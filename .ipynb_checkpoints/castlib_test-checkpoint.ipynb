# %%
import datetime
from dateutil.relativedelta import relativedelta
import time
import json
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from castlib.cast import Cast
from castlib.reporter import Reporter
from castlib.prop import Prop
from castlib.event import Event

import pandas as pd

# %%
d = datetime.date

def AccountProp(name, amount):
        return Event(name=f"cashout {name}", amount=amount, date=d.today())

Guideline = AccountProp("401k", 8500 * 1)
Robinhood = AccountProp("Robinhood", 1500)
Wealthfront = AccountProp("Schwab", 9000)

# Cash
mattress_equity = 3000
personal_capital_cash = 10000 + mattress_payment

c = (Cast(balance=personal_capital_cash)
     .end_after(months=18)
     .report_with(Reporter)

     .add_event(Event(name="Rent", amount=-2600, date=d(2020, 2, 1)).monthly) # $1,900 $2,100
     .add_event(Event(name="Furniture", amount=-2500, date=d(2020, 8, 1)))
     
     # start paying progressive again
     .add_event(Event(name="Progressive", amount=-250, date=d(2020, 6, 1)).monthly)

     .add_event(Event(name="Carmax", amount=-910, date=d(2020, 5, 16)).monthly)
     .add_event(Event(name="Utilities", amount=-200, date=d(2020, 3, 15)).monthly)
     .add_event(Event(name="Sprint", amount=-250, date=d(2020, 3, 15), end=d(2020, 9 , 1)).monthly)
     .add_event(Event(name="Medical", amount=-100, date=d(2020, 3, 15)).monthly)

     .add_event(Event(name="Food", amount=-150, date=d(2020, 2, 2)).weekly)
     
     .add_event([Guideline, Wealthfront, Robinhood])
     .add_event(Event(name="payout2", amount=5500, date=d(2021, 1, 1)))

     .save(f"/Users/jacobsansbury/Casts/fired-{d.today()}.json")
)

# %%
# events
boeing_work = Prop([Event(name="Boeing Work", amount=4000, date=d(2020, 7, 1))], name="Boeing Work")

scenarios = [boeing_work]

_all = scenarios[0]

for scenario in scenarios[1:]:
    _all += scenario
    
print(_all.name)
    
_all.name="All"

scenarios.append(_all)

c.report.running_balance(props=scenarios);
# Out:
# Boeing Work

# %% [markdown]
# # Sum of Scenarios > Sum of Parts
#
# Observe below: the sum of scenarios "All" gives us more time than the sum of each scenario. The scenarios increase the value of each other.
#
# For example: when we move to a cheaper appartment — the money from my family goes further

# %%
pd.DataFrame(c.report.days_till_broke(props=scenarios), columns=("Scenario", "Months 'till Broke", "Change from Base"))
# Out:
#   Scenario Months 'till Broke Change from Base
# 0  Default                7.6             -0.0
# 1      All                8.1             +0.5

# %%
(d.today() + datetime.timedelta(days=(float(c.report.days_till_broke(props=[_all])[1][1]) * 30))).__str__()
# Out:
# '2021-03-01'

# %%
old = c.fromfile("/Users/jacobsansbury/Casts/fired-2020-02-28.json")

# %%
old.report_with(Reporter)
old.report.running_balance();
pd.DataFrame(old.report.days_till_broke(props=[]), columns=("Scenario", "Months 'till Broke", "Change from Base"))
# Out:
#   Scenario Months 'till Broke Change from Base
# 0  Default                5.5             -0.0

# %%
(d.today() + datetime.timedelta(days=(float(old.report.days_till_broke(props=[_all])[1][1]) * 30))).__str__()
# Out:
# '2020-12-01'
