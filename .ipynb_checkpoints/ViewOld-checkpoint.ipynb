# %%
from castlib.cast import Cast
from castlib.reporter import Reporter
from castlib.prop import Prop
from castlib.event import Event

import datetime

d = datetime.date

# %%
origin_plan = "NVIDIA-2020-10-25"
names = [origin_plan, "NVIDIA-2020-12-01", "NVIDIA-2020-12-04", "NVIDIA-2020-12-27"]
names = reversed(names)

for name in names:
    a = Cast.fromfile(f"/Users/jacobsansbury/Casts/{name}.json").report_with(Reporter).end_after(years=4)
    a.report.running_balance(title=name, mark_today=True, annotate=[d(2021, 12, 31)])
